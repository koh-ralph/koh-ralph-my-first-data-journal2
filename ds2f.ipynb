# %% [markdown]
# <a href="https://colab.research.google.com/github/koh-ralph/koh-ralph-my-first-data-journal2/blob/main/ds2f.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my first commit.")
# Out:
# Hello, GitHub! This is my first commit.

# %%
print("Hello, GitHub! This is my second commit.")
# Out:
# Hello, GitHub! This is my second commit.
